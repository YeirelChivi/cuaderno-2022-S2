# %% [markdown]
# <a href="https://colab.research.google.com/github/YeirelChivi/cuaderno-2022-S2/blob/main/Cuaderno_de_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Semana 1 - Pseudocodigo

# %% [markdown]
# ## Contador de digitos
#
# usando Pseint crear un diagrama de flujo para representar el flujo y pseudocodigo para el algoritmo de contarDigitos
#
# - Recibira dos parametros
# - Ambos mayores a cero

# %% [markdown]
# ### Diagrama de flujo
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Pseudocodigo
#
#
#
# ```
# Algoritmo contarDigitos
#     total <- 0
#     Leer a
#     Mientras a > 0 Hacer
#         // Realiza la operación
#         a <- trunc(a / 10)
#         total <- total + 1
#     FinMientras
#     Escribir total
#
# FinAlgoritmo
# ```
